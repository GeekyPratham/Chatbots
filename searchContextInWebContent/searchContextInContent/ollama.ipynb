# %%
import os 
from dotenv import load_dotenv
load_dotenv() ## for loading all the variable from the env file

# os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY") 


## langchain api key is used for langsmith tracking
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="True"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
# from langchain_community.chat_models import ChatOllama
# llm = ChatOllama()
# print(llm)

## abvoe give warning because langchain due to its multiple providers(openai,anthropic,gemini,etc) into seperate integration to make maintenance easier ,versioning cleaner ,dependency conflicts lower

from langchain_ollama.chat_models import ChatOllama
llm = ChatOllama(
    model="gemma:2b"
)
print(llm)
# Out:
# model='gemma:2b'

# %%
## Input and get response as output from llm
response = llm.invoke("what is genAi in five points")

# %%
print(response.content)
# Out:
# Sure, here's a summary of genAI in five points:
#
# 1. **Generative AI:** genAI is a powerful AI language model that focuses on **text generation** rather than language translation. It excels at creating various types of creative content, including poems, code, scripts, musical pieces, and more.
#
#
# 2. **Large Language Model (LLM):** genAI is a large language model (LLM) with a massive dataset of over 175 billion parameters. This allows it to understand and generate human-quality text.
#
#
# 3. **Text-Centric:** genAI primarily focuses on generating **text** rather than translating between different languages. This enables it to understand the context and meaning of the text it generates, leading to more natural and coherent outputs.
#
#
# 4. **Multimodal:** genAI can generate content in multiple formats, including text, code, images, and music. This makes it a versatile tool for various creative and content creation tasks.
#
#
# 5. **Applications:** genAI has various applications, including:
#     - Content creation (stories, poems, music)
#     - Language modeling
#     - Chatbots and conversational AI
#     - Summarization
#     - Text-based games and interactive storytelling

# %%
response = llm.invoke("what is langchain")

# %%
print(response.content)
# Out:
# **LangChain** is a novel, scalable, and interoperable language model that utilizes a unique approach to language representation and processing called **"ChainNet."**
#
# **ChainNet** is a neural network architecture that allows LangChain to:
#
# * **Represent natural language using a sequence of symbols.**
# * **Generate new text and translate between languages.**
# * **Develop new computational methods.**
#
# **Key features of LangChain:**
#
# * **ChainNet:** A neural network architecture that represents language as a sequence of symbols.
# * **Scalability:** LangChain is designed to be efficient and handle large amounts of data.
# * **Interoperability:** It can be integrated with existing systems and models.
# * **Novelty:** LangChain introduces novel ideas in natural language processing, such as symbol grounding and context-dependent attention.
#
# **Here's how LangChain works:**
#
# 1. **Sentence representation:** LangChain tokenizes the input sentence into a sequence of symbols.
# 2. **ChainNet training:** The symbols are fed into a ChainNet, which learns to generate new symbols based on the sequence.
# 3. **Language modeling:** LangChain can generate new text, translate between languages, and perform other language-related tasks.
#
# **Benefits of LangChain:**
#
# * **Enhanced efficiency:** ChainNet's symbol grounding reduces the need for complex attention mechanisms.
# * **Improved scalability:** LangChain can handle massive datasets and generate text in real-time.
# * **New possibilities:** It opens up possibilities for novel applications in natural language processing.
#
# **Use cases for LangChain include:**
#
# * **Language modeling:** Text generation, machine translation, and language teaching.
# * **Code generation:** Generating code in various programming languages.
# * **Drug discovery:** Identifying and developing new therapeutic agents.
# * **Content creation:** Creating new text formats, such as music and images.
#
# **In conclusion,** LangChain is a significant breakthrough in natural language processing. Its unique approach to representation and processing promises to revolutionize how we interact with and create language-based systems.

# %%
## Chatprompt tamplet -> role defined to llm model or what kind response we want from llm
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate(
    [
        ("system","You are an expert AI engineer. Provide me answer based on qeustion"),
        ("user","{input}")
    ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI engineer. Provide me answer based on qeustion'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
## Chain A pipeline designed specifically for LLM workflows, often with:

# prompts
# models
# memory
# retrievers
# tools
# parsers

chain = prompt | llm
response = chain.invoke({
    "input" : "Can you tell me about langsmith?"
})
print(response)
# Out:
# content="**Sure, I can tell you about Langsmith.**\n\n**Langsmith** is a natural language processing (NLP) company that specializes in building **conversational AI models** for a variety of applications, including customer service, marketing, and education.\n\n**Key features of Langsmith include:**\n\n* **Natural language understanding (NLU)**: Langsmith's models are trained on massive datasets of text and code, allowing them to understand and generate human-like text.\n* **Conversational AI**: They develop conversational AI models that can engage in natural and intuitive conversations with users.\n* **Domain-specific models**: Langsmith offers specialized NLP models for specific industries, such as healthcare, finance, and education.\n* **Easy to use**: Their platform provides developers with a drag-and-drop interface to create and customize conversational AI models.\n* **AI as a Service**: Langsmith offers a service called AI as a Service, where they provide businesses with access to their NLP models on a subscription basis.\n\n**Benefits of using Langsmith include:**\n\n* **Improved customer experiences**: By providing seamless and personalized interactions, businesses can enhance customer satisfaction.\n* **Increased marketing effectiveness**: AI-powered chatbots can automate marketing tasks and generate targeted content, leading to better lead generation and conversion rates.\n* **Enhanced education**: NLP models can provide personalized learning experiences and automate educational support.\n* **Reduced costs**: By automating tasks and improving customer support, businesses can save money on operational costs.\n\n**Overall, Langsmith is a leading provider of natural language processing solutions that can help businesses of all sizes improve their customer experiences, increase marketing effectiveness, and enhance education.**" additional_kwargs={} response_metadata={'model': 'gemma:2b', 'created_at': '2026-03-31T05:22:56.1498088Z', 'done': True, 'done_reason': 'stop', 'total_duration': 17492909700, 'load_duration': 298387700, 'prompt_eval_count': 45, 'prompt_eval_duration': 334125000, 'eval_count': 342, 'eval_duration': 15493271000, 'logprobs': None, 'model_name': 'gemma:2b', 'model_provider': 'ollama'} id='lc_run--019d4258-07c0-75a1-a56e-fc0301c7f129-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 45, 'output_tokens': 342, 'total_tokens': 387}

# %%
print(type(response))
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>

# %%
print(response.content)
# Out:
# **Sure, I can tell you about Langsmith.**
#
# **Langsmith** is a natural language processing (NLP) company that specializes in building **conversational AI models** for a variety of applications, including customer service, marketing, and education.
#
# **Key features of Langsmith include:**
#
# * **Natural language understanding (NLU)**: Langsmith's models are trained on massive datasets of text and code, allowing them to understand and generate human-like text.
# * **Conversational AI**: They develop conversational AI models that can engage in natural and intuitive conversations with users.
# * **Domain-specific models**: Langsmith offers specialized NLP models for specific industries, such as healthcare, finance, and education.
# * **Easy to use**: Their platform provides developers with a drag-and-drop interface to create and customize conversational AI models.
# * **AI as a Service**: Langsmith offers a service called AI as a Service, where they provide businesses with access to their NLP models on a subscription basis.
#
# **Benefits of using Langsmith include:**
#
# * **Improved customer experiences**: By providing seamless and personalized interactions, businesses can enhance customer satisfaction.
# * **Increased marketing effectiveness**: AI-powered chatbots can automate marketing tasks and generate targeted content, leading to better lead generation and conversion rates.
# * **Enhanced education**: NLP models can provide personalized learning experiences and automate educational support.
# * **Reduced costs**: By automating tasks and improving customer support, businesses can save money on operational costs.
#
# **Overall, Langsmith is a leading provider of natural language processing solutions that can help businesses of all sizes improve their customer experiences, increase marketing effectiveness, and enhance education.**

# %%
## String output parser is used to disply the output or message or response

from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()
chain = prompt | llm | output_parser

response = chain.invoke({
    "input" : "Can you tell me about langsmith?"
})
print(chain)
# Out:
# first=ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI engineer. Provide me answer based on qeustion'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})]) middle=[ChatOllama(model='gemma:2b')] last=StrOutputParser()

# %%
print(response)
# Out:
# Sure, here's an answer to your question about Langsmith:
#
# **Langsmith** is a specialized open-source AI language model designed to understand and generate human-like text. It is a highly advanced machine learning model that has been trained on a massive dataset of text and code.
#
# **Key characteristics of Langsmith include:**
#
# * **Natural language understanding (NLU):** It can understand and generate human-like text on a wide range of topics and formats, including natural language, code, and technical documents.
# * **Language generation:** It can generate new text in a specific language or on a given topic.
# * **Code generation:** It can generate code in various programming languages, including Python, Java, and C++.
# * **Domain knowledge:** It has been pre-trained on a massive dataset of text and code, including Wikipedia and a wide range of technical and scientific papers.
# * **Open-source:** It is an open-source project, meaning its source code is freely available for anyone to use and modify.
#
# **Uses of Langsmith:**
#
# * **Text generation:** It can be used to generate new text for various purposes, such as marketing copy, articles, and social media posts.
# * **Code creation:** It can assist developers by generating code snippets and suggesting solutions to programming problems.
# * **Language translation:** It can translate text between multiple languages with high accuracy.
# * **Language learning:** It can be used as a language learning tool to teach new languages by providing interactive exercises and conversation prompts.
#
# **Limitations of Langsmith:**
#
# * **Bias and ethical considerations:** While Langsmith is trained on a massive dataset, it can still reflect biases present in the data.
# * **Lack of real-world knowledge:** It does not have access to real-world knowledge or experiences, which can limit its understanding of certain topics.
# * **Computational requirements:** Training and using Langsmith can be computationally intensive.
#
# **Overall, Langsmith is a powerful AI language model with a wide range of applications. It is a valuable tool for developers, language learners, and anyone looking to explore the capabilities of artificial intelligence.**

# %%
## Data ingestion -> from website we need to scrape the data 
from langchain_community.document_loaders import WebBaseLoader
loader = WebBaseLoader(
    "https://docs.langchain.com/langsmith/home",
    verify_ssl=False
)
print(loader)
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# <langchain_community.document_loaders.web_base.WebBaseLoader object at 0x00000213C5DFEE30>

# %%
docs = loader.load()
""" 
loader.load() actual webpage par jaata hai aur:

HTML fetch karta hai
readable text nikalta hai
usko LangChain ke Document format me convert karta hai

"""
print(docs)
# Out:
# d:\MindsprintCourse\GenAI_Apps\searchContextInWebContent\venv\lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'docs.langchain.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# [Document(metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='LangSmith docs - Docs by LangChainSkip to main contentJoin us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. Buy tickets >Docs by LangChain home pageLangSmithSearch...⌘KAsk AIGitHubTry LangSmithTry LangSmithSearch...NavigationLangSmith docsGet startedObservabilityEvaluationPrompt engineeringAgent deploymentPlatform setupReferenceOverviewCreate an account and API keyIntegrationsPlansEnterprise featuresAccount administrationOverviewWorkspace setupUsers & access controlBilling & usageManage organizations using the APIToolsPolly AI assistantCLISkillsSandboxesPrivate previewAdditional resourcesData & complianceFAQLangSmith statusLangSmith docsCopy pageCopy pageLangSmith is a framework-agnostic platform for building, debugging, and deploying AI agents and LLM applications. Trace requests, evaluate outputs, test prompts, and manage deployments all in one place, with your agent stack.\n\u200bGet started\nCreate an accountSign up at smith.langchain.com (no credit card required).\nYou can log in with Google, GitHub, or email.Create an API keyGo to your Settings page → API Keys → Create API Key.\nCopy the key and save it securely.Choose your integrationLangSmith works with many frameworks and providers. Browse available integrations to connect your stack.\nOnce your account and API key are ready, choose a quickstart to begin building with LangSmith:\nObservabilityGain visibility into every step your application takes to debug faster and improve reliability.Start tracingEvaluationMeasure and track quality over time to ensure your AI applications are consistent and trustworthy.Evaluate your appDeploymentDeploy your agents as Agent Servers, ready to scale in production.Deploy your agents\n\u200bMore ways to build\nFleetDesign and deploy AI agents visually without writing code.Build an agentPrompt engineeringIterate on prompts with built-in versioning and collaboration to ship improvements faster.Test your promptsLangSmith CLIQuery and manage traces, datasets, experiments, and more from the terminal.Use the CLIStudioUse a visual interface to design, test, and refine applications end-to-end.Develop with Studio\n\u200bInfrastructure\nPlatform setupUse LangSmith in managed cloud, in a self-hosted environment, or hybrid to match your infrastructure and compliance needs.Choose how to set up LangSmithSecurity & complianceLangSmith meets the highest standards of data security and privacy with HIPAA, SOC 2 Type 2, and GDPR compliance.Visit Trust Center\n\u200bWorkflow\nLangSmith combines observability, evaluation, deployment, and platform setup in one integrated workflow—from local development to production.\n\n\n\nEdit this page on GitHub or file an issue.Connect these docs to Claude, VSCode, and more via MCP for real-time answers.Was this page helpful?YesNoCreate an account and API keyNext⌘IDocs by LangChain home pagegithubxlinkedinyoutubeResourcesForumChangelogLangChain AcademyTrust CenterCompanyHomeAboutCareersBloggithubxlinkedinyoutube\n')]

# %% [markdown]
# # load the data
# # convert it into docs
# # divide our text into chunks
# # convert chunks into vector embedding
# # store it into vector store db

# %%
from  langchain_text_splitters import RecursiveCharacterTextSplitter
""" 
RecursiveCharacterTextSplitter --> Text ko manageable pieces me tod do, lekin possible ho toh sentences/paragraphs ka meaning bana rahe.
"""

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200)

""" 

Problem: Hum pura webpage ek saath kyu nahi use karte?

Socho webpage me 20,000 characters ka content hai.

Agar tum pura content LLM ko de doge:

context window waste hoga
retrieval weak ho jayega
irrelevant information bahut jayegi
embeddings quality degrade ho sakti hai

Isliye hum content ko small meaningful pieces (chunks) me todte hain.

"""
documents = text_splitter.split_documents(docs)

# %%
print(documents)
# Out:
# [Document(metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='LangSmith docs - Docs by LangChainSkip to main contentJoin us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. Buy tickets >Docs by LangChain home pageLangSmithSearch...⌘KAsk AIGitHubTry LangSmithTry LangSmithSearch...NavigationLangSmith docsGet startedObservabilityEvaluationPrompt engineeringAgent deploymentPlatform setupReferenceOverviewCreate an account and API keyIntegrationsPlansEnterprise featuresAccount administrationOverviewWorkspace setupUsers & access controlBilling & usageManage organizations using the APIToolsPolly AI assistantCLISkillsSandboxesPrivate previewAdditional resourcesData & complianceFAQLangSmith statusLangSmith docsCopy pageCopy pageLangSmith is a framework-agnostic platform for building, debugging, and deploying AI agents and LLM applications. Trace requests, evaluate outputs, test prompts, and manage deployments all in one place, with your agent stack.\n\u200bGet started\nCreate an accountSign up at smith.langchain.com (no credit card required).'), Document(metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='\u200bGet started\nCreate an accountSign up at smith.langchain.com (no credit card required).\nYou can log in with Google, GitHub, or email.Create an API keyGo to your Settings page → API Keys → Create API Key.\nCopy the key and save it securely.Choose your integrationLangSmith works with many frameworks and providers. Browse available integrations to connect your stack.\nOnce your account and API key are ready, choose a quickstart to begin building with LangSmith:\nObservabilityGain visibility into every step your application takes to debug faster and improve reliability.Start tracingEvaluationMeasure and track quality over time to ensure your AI applications are consistent and trustworthy.Evaluate your appDeploymentDeploy your agents as Agent Servers, ready to scale in production.Deploy your agents\n\u200bMore ways to build'), Document(metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='\u200bMore ways to build\nFleetDesign and deploy AI agents visually without writing code.Build an agentPrompt engineeringIterate on prompts with built-in versioning and collaboration to ship improvements faster.Test your promptsLangSmith CLIQuery and manage traces, datasets, experiments, and more from the terminal.Use the CLIStudioUse a visual interface to design, test, and refine applications end-to-end.Develop with Studio\n\u200bInfrastructure\nPlatform setupUse LangSmith in managed cloud, in a self-hosted environment, or hybrid to match your infrastructure and compliance needs.Choose how to set up LangSmithSecurity & complianceLangSmith meets the highest standards of data security and privacy with HIPAA, SOC 2 Type 2, and GDPR compliance.Visit Trust Center\n\u200bWorkflow\nLangSmith combines observability, evaluation, deployment, and platform setup in one integrated workflow—from local development to production.'), Document(metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='Edit this page on GitHub or file an issue.Connect these docs to Claude, VSCode, and more via MCP for real-time answers.Was this page helpful?YesNoCreate an account and API keyNext⌘IDocs by LangChain home pagegithubxlinkedinyoutubeResourcesForumChangelogLangChain AcademyTrust CenterCompanyHomeAboutCareersBloggithubxlinkedinyoutube')]

# %%
documents
# Out:
# [Document(metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='LangSmith docs - Docs by LangChainSkip to main contentJoin us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. Buy tickets >Docs by LangChain home pageLangSmithSearch...⌘KAsk AIGitHubTry LangSmithTry LangSmithSearch...NavigationLangSmith docsGet startedObservabilityEvaluationPrompt engineeringAgent deploymentPlatform setupReferenceOverviewCreate an account and API keyIntegrationsPlansEnterprise featuresAccount administrationOverviewWorkspace setupUsers & access controlBilling & usageManage organizations using the APIToolsPolly AI assistantCLISkillsSandboxesPrivate previewAdditional resourcesData & complianceFAQLangSmith statusLangSmith docsCopy pageCopy pageLangSmith is a framework-agnostic platform for building, debugging, and deploying AI agents and LLM applications. Trace requests, evaluate outputs, test prompts, and manage deployments all in one place, with your agent stack.\n\u200bGet started\nCreate an accountSign up at smith.langchain.com (no credit card required).'),
#  Document(metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='\u200bGet started\nCreate an accountSign up at smith.langchain.com (no credit card required).\nYou can log in with Google, GitHub, or email.Create an API keyGo to your Settings page → API Keys → Create API Key.\nCopy the key and save it securely.Choose your integrationLangSmith works with many frameworks and providers. Browse available integrations to connect your stack.\nOnce your account and API key are ready, choose a quickstart to begin building with LangSmith:\nObservabilityGain visibility into every step your application takes to debug faster and improve reliability.Start tracingEvaluationMeasure and track quality over time to ensure your AI applications are consistent and trustworthy.Evaluate your appDeploymentDeploy your agents as Agent Servers, ready to scale in production.Deploy your agents\n\u200bMore ways to build'),
#  Document(metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='\u200bMore ways to build\nFleetDesign and deploy AI agents visually without writing code.Build an agentPrompt engineeringIterate on prompts with built-in versioning and collaboration to ship improvements faster.Test your promptsLangSmith CLIQuery and manage traces, datasets, experiments, and more from the terminal.Use the CLIStudioUse a visual interface to design, test, and refine applications end-to-end.Develop with Studio\n\u200bInfrastructure\nPlatform setupUse LangSmith in managed cloud, in a self-hosted environment, or hybrid to match your infrastructure and compliance needs.Choose how to set up LangSmithSecurity & complianceLangSmith meets the highest standards of data security and privacy with HIPAA, SOC 2 Type 2, and GDPR compliance.Visit Trust Center\n\u200bWorkflow\nLangSmith combines observability, evaluation, deployment, and platform setup in one integrated workflow—from local development to production.'),
#  Document(metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='Edit this page on GitHub or file an issue.Connect these docs to Claude, VSCode, and more via MCP for real-time answers.Was this page helpful?YesNoCreate an account and API keyNext⌘IDocs by LangChain home pagegithubxlinkedinyoutubeResourcesForumChangelogLangChain AcademyTrust CenterCompanyHomeAboutCareersBloggithubxlinkedinyoutube')]

# %%
## embedding it into vector
from langchain_community.embeddings import OllamaEmbeddings
embeddings = OllamaEmbeddings(
    model="gemma:2b"
)

""" 
gemma:2b ek chat/generative model hai, dedicated embedding model nahi.

Ollama embeddings ke liye better models hote hain jaise:

nomic-embed-text
mxbai-embed-large
all-minilm

"""
# Out:
# C:\Users\pratham.raj\AppData\Local\Temp\ipykernel_27784\930126846.py:3: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaEmbeddings``.
#   embeddings = OllamaEmbeddings(
# ' \ngemma:2b ek chat/generative model hai, dedicated embedding model nahi.\n\nOllama embeddings ke liye better models hote hain jaise:\n\nnomic-embed-text\nmxbai-embed-large\nall-minilm\n\n'

# %%
## store it into vector db faiss
from langchain_community.vectorstores import FAISS #Facebook AI Similarity Search
vectorStore = FAISS.from_documents(documents,embeddings)
""" 
meaning of above line
1. Har document chunk ka embedding banata hai
2. Un embeddings ko index karta hai
3. Unko searchable vector store me daal deta hai

"""



"""  

Normal keyword search:

“debugging” word dhundega

Vector search:

“trace”, “evaluation”, “monitoring”, “observability” jaisi semantically similar cheeze bhi samajh lega

"""
# Out:
# '  \n\nNormal keyword search:\n\n“debugging” word dhundega\n\nVector search:\n\n“trace”, “evaluation”, “monitoring”, “observability” jaisi semantically similar cheeze bhi samajh lega\n\n'

# %%
## querying in vector db
query = "LangSmith is a framework-agnostic platform for developing, debugging,"
result = vectorStore.similarity_search_with_score(query)
print(result)
# Out:
# [(Document(id='37512f23-04bd-4cf3-b6dd-7ec4e3a62bab', metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='\u200bMore ways to build\nFleetDesign and deploy AI agents visually without writing code.Build an agentPrompt engineeringIterate on prompts with built-in versioning and collaboration to ship improvements faster.Test your promptsLangSmith CLIQuery and manage traces, datasets, experiments, and more from the terminal.Use the CLIStudioUse a visual interface to design, test, and refine applications end-to-end.Develop with Studio\n\u200bInfrastructure\nPlatform setupUse LangSmith in managed cloud, in a self-hosted environment, or hybrid to match your infrastructure and compliance needs.Choose how to set up LangSmithSecurity & complianceLangSmith meets the highest standards of data security and privacy with HIPAA, SOC 2 Type 2, and GDPR compliance.Visit Trust Center\n\u200bWorkflow\nLangSmith combines observability, evaluation, deployment, and platform setup in one integrated workflow—from local development to production.'), np.float32(3744.832)), (Document(id='5790f6a8-9dd6-4736-9af5-aac30c72ef77', metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='\u200bGet started\nCreate an accountSign up at smith.langchain.com (no credit card required).\nYou can log in with Google, GitHub, or email.Create an API keyGo to your Settings page → API Keys → Create API Key.\nCopy the key and save it securely.Choose your integrationLangSmith works with many frameworks and providers. Browse available integrations to connect your stack.\nOnce your account and API key are ready, choose a quickstart to begin building with LangSmith:\nObservabilityGain visibility into every step your application takes to debug faster and improve reliability.Start tracingEvaluationMeasure and track quality over time to ensure your AI applications are consistent and trustworthy.Evaluate your appDeploymentDeploy your agents as Agent Servers, ready to scale in production.Deploy your agents\n\u200bMore ways to build'), np.float32(4240.901)), (Document(id='662bf544-abd3-4964-88fb-886de4149264', metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='LangSmith docs - Docs by LangChainSkip to main contentJoin us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. Buy tickets >Docs by LangChain home pageLangSmithSearch...⌘KAsk AIGitHubTry LangSmithTry LangSmithSearch...NavigationLangSmith docsGet startedObservabilityEvaluationPrompt engineeringAgent deploymentPlatform setupReferenceOverviewCreate an account and API keyIntegrationsPlansEnterprise featuresAccount administrationOverviewWorkspace setupUsers & access controlBilling & usageManage organizations using the APIToolsPolly AI assistantCLISkillsSandboxesPrivate previewAdditional resourcesData & complianceFAQLangSmith statusLangSmith docsCopy pageCopy pageLangSmith is a framework-agnostic platform for building, debugging, and deploying AI agents and LLM applications. Trace requests, evaluate outputs, test prompts, and manage deployments all in one place, with your agent stack.\n\u200bGet started\nCreate an accountSign up at smith.langchain.com (no credit card required).'), np.float32(4265.6875)), (Document(id='aa7e8a83-4d41-4a23-9490-4227c8be22f1', metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='Edit this page on GitHub or file an issue.Connect these docs to Claude, VSCode, and more via MCP for real-time answers.Was this page helpful?YesNoCreate an account and API keyNext⌘IDocs by LangChain home pagegithubxlinkedinyoutubeResourcesForumChangelogLangChain AcademyTrust CenterCompanyHomeAboutCareersBloggithubxlinkedinyoutube'), np.float32(5752.277 ...

# %%
result
# Out:
# [(Document(id='37512f23-04bd-4cf3-b6dd-7ec4e3a62bab', metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='\u200bMore ways to build\nFleetDesign and deploy AI agents visually without writing code.Build an agentPrompt engineeringIterate on prompts with built-in versioning and collaboration to ship improvements faster.Test your promptsLangSmith CLIQuery and manage traces, datasets, experiments, and more from the terminal.Use the CLIStudioUse a visual interface to design, test, and refine applications end-to-end.Develop with Studio\n\u200bInfrastructure\nPlatform setupUse LangSmith in managed cloud, in a self-hosted environment, or hybrid to match your infrastructure and compliance needs.Choose how to set up LangSmithSecurity & complianceLangSmith meets the highest standards of data security and privacy with HIPAA, SOC 2 Type 2, and GDPR compliance.Visit Trust Center\n\u200bWorkflow\nLangSmith combines observability, evaluation, deployment, and platform setup in one integrated workflow—from local development to production.'),
#   np.float32(3744.832)),
#  (Document(id='5790f6a8-9dd6-4736-9af5-aac30c72ef77', metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='\u200bGet started\nCreate an accountSign up at smith.langchain.com (no credit card required).\nYou can log in with Google, GitHub, or email.Create an API keyGo to your Settings page → API Keys → Create API Key.\nCopy the key and save it securely.Choose your integrationLangSmith works with many frameworks and providers. Browse available integrations to connect your stack.\nOnce your account and API key are ready, choose a quickstart to begin building with LangSmith:\nObservabilityGain visibility into every step your application takes to debug faster and improve reliability.Start tracingEvaluationMeasure and track quality over time to ensure your AI applications are consistent and trustworthy.Evaluate your appDeploymentDeploy your agents as Agent Servers, ready to scale in production.Deploy your agents\n\u200bMore ways to build'),
#   np.float32(4240.901)),
#  (Document(id='662bf544-abd3-4964-88fb-886de4149264', metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='LangSmith docs - Docs by LangChainSkip to main contentJoin us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. Buy tickets >Docs by LangChain home pageLangSmithSearch...⌘KAsk AIGitHubTry LangSmithTry LangSmithSearch...NavigationLangSmith docsGet startedObservabilityEvaluationPrompt engineeringAgent deploymentPlatform setupReferenceOverviewCreate an account and API keyIntegrationsPlansEnterprise featuresAccount administrationOverviewWorkspace setupUsers & access controlBilling & usageManage organizations using the APIToolsPolly AI assistantCLISkillsSandboxesPrivate previewAdditional resourcesData & complianceFAQLangSmith statusLangSmith docsCopy pageCopy pageLangSmith is a framework-agnostic platform for building, debugging, and deploying AI agents and LLM applications. Trace requests, evaluate outputs, test prompts, and manage deployments all in one place, with your agent stack.\n\u200bGet started\nCreate an accountSign up at smith.langchain.com (no credit card required).'),
#   np.float32(4265.6875)),
#  (Document(id='aa7e8a83-4d41-4a23-9490-4227c8be22f1', metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='Edit this page on GitHub or file an issue.Connect these docs to Claude, VSCode, and more via MCP for real-time answers.Was this page helpful?YesNoCreate an account and API keyNext⌘IDocs by LangChain home pagegithubxlinkedinyoutubeResourcesForumChangelogLangChain AcademyTrust CenterCompanyHomeAboutCareersBloggithubxlinkedinyoutube'),
#   np.float32(5752.2773))]

# %%
for res in result:
    print(res[0].page_content)
# Out:
# ​More ways to build
# FleetDesign and deploy AI agents visually without writing code.Build an agentPrompt engineeringIterate on prompts with built-in versioning and collaboration to ship improvements faster.Test your promptsLangSmith CLIQuery and manage traces, datasets, experiments, and more from the terminal.Use the CLIStudioUse a visual interface to design, test, and refine applications end-to-end.Develop with Studio
# ​Infrastructure
# Platform setupUse LangSmith in managed cloud, in a self-hosted environment, or hybrid to match your infrastructure and compliance needs.Choose how to set up LangSmithSecurity & complianceLangSmith meets the highest standards of data security and privacy with HIPAA, SOC 2 Type 2, and GDPR compliance.Visit Trust Center
# ​Workflow
# LangSmith combines observability, evaluation, deployment, and platform setup in one integrated workflow—from local development to production.
# ​Get started
# Create an accountSign up at smith.langchain.com (no credit card required).
# You can log in with Google, GitHub, or email.Create an API keyGo to your Settings page → API Keys → Create API Key.
# Copy the key and save it securely.Choose your integrationLangSmith works with many frameworks and providers. Browse available integrations to connect your stack.
# Once your account and API key are ready, choose a quickstart to begin building with LangSmith:
# ObservabilityGain visibility into every step your application takes to debug faster and improve reliability.Start tracingEvaluationMeasure and track quality over time to ensure your AI applications are consistent and trustworthy.Evaluate your appDeploymentDeploy your agents as Agent Servers, ready to scale in production.Deploy your agents
# ​More ways to build
# LangSmith docs - Docs by LangChainSkip to main contentJoin us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. Buy tickets >Docs by LangChain home pageLangSmithSearch...⌘KAsk AIGitHubTry LangSmithTry LangSmithSearch...NavigationLangSmith docsGet startedObservabilityEvaluationPrompt engineeringAgent deploymentPlatform setupReferenceOverviewCreate an account and API keyIntegrationsPlansEnterprise featuresAccount administrationOverviewWorkspace setupUsers & access controlBilling & usageManage organizations using the APIToolsPolly AI assistantCLISkillsSandboxesPrivate previewAdditional resourcesData & complianceFAQLangSmith statusLangSmith docsCopy pageCopy pageLangSmith is a framework-agnostic platform for building, debugging, and deploying AI agents and LLM applications. Trace requests, evaluate outputs, test prompts, and manage deployments all in one place, with your agent stack.
# ​Get started
# Create an accountSign up at smith.langchain.com (no credit card required).
# Edit this page on GitHub or file an issue.Connect these docs to Claude, VSCode, and more via MCP for real-time answers.Was this page helpful?YesNoCreate an account and API keyNext⌘IDocs by LangChain home pagegithubxlinkedinyoutubeResourcesForumChangelogLangChain AcademyTrust CenterCompanyHomeAboutCareersBloggithubxlinkedinyoutube

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(
    model="gemma:2b"
)
print(llm)
# Out:
# model='gemma:2b'

# %%
## retrieval chain , document chain
from langchain_classic.chains.combine_documents import create_stuff_documents_chain ##Sare retrieved documents ko ek saath prompt me bhar dena
# this helps us to make a document chain
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_template(
    """
    Answer the following question based on the the provided context:
    <context>
    {context}
    </context>

"""
)
document_chain = create_stuff_documents_chain(llm,prompt)

"""
Ye ek chain bana raha hai jo:

    documents ko lega
    unko format karega
    prompt me {context} me daalega
    LLM ko bhejega
    answer return karega

"""
document_chain
# Out:
# RunnableBinding(bound=RunnableBinding(bound=RunnableAssign(mapper={
#   context: RunnableLambda(format_docs)
# }), kwargs={}, config={'run_name': 'format_inputs'}, config_factories=[])
# | ChatPromptTemplate(input_variables=['context'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context'], input_types={}, partial_variables={}, template='\n    Answer the following question based on the the provided context:\n    <context>\n    {context}\n    </context>\n\n'), additional_kwargs={})])
# | ChatOllama(model='gemma:2b')
# | StrOutputParser(), kwargs={}, config={'run_name': 'stuff_documents_chain'}, config_factories=[])

# %%
from langchain_core.documents import Document


document_chain.invoke({
    "input":"LangSmith is a framework-agnostic platform for developing, debugging,",
    "context":[Document(page_content="LangSmith is a framework-agnostic platform for developing, debugging, and deploying AI agents and LLM applications. It helps you trace requests, evaluate outputs, test prompts, and manage deployments in one place. LangSmith works with any agent stack, whether you’re using an existing framework or building your own. Prototype locally, then move to production with integrated monitoring and evaluation to build more reliable AI agents.")]
})


""" 
ishme kya ho raha isme ham document kudh ka bhej rahe hai maan le ki document retrieve hone ke bad mila hai aur , ham apna input dia hai chain ko toh chain mera context lega document and input , llm ush document(retrieval chunk jab ham search karke nikale ge chunk) se search karke result dega

"""
# Out:
# ' \nishme kya ho raha isme ham document kudh ka bhej rahe hai maan le ki document retrieve hone ke bad mila hai aur , ham apna input dia hai chain ko toh chain mera context lega document and input , llm ush document(retrieval chunk jab ham search karke nikale ge chunk) se search karke result dega\n\n'

# %% [markdown]
# However we want the documents first come from the retriever we just set up. That way, we can use the retriever to dynamically select the most relevant documents and pass those in for a given qeustion

# %%
## ham log upar me document(context ) bhej rahe the wah document ke form me hard coded tha
## magar actual me retrive document (context, chunk ) ke basis par bhejna hota hai

# %%
## Retriever
""" 
input come -> goes to retrieva(act as interface) -> bring the relevant data from the vectorStore db .

so we have to convert vectorStore db into retriever

and we even dont have to do similarity search retriever does for us.
"""
vectorStore

# %%
retriever = vectorStore.as_retriever() # convert vectorStore db into retriever

# %%
from langchain_classic.chains import create_retrieval_chain
retrieval_chain = create_retrieval_chain(retriever,document_chain)
## this take out relevant context from the db and fill the context into the prompt and then we can invoke prompt with llm

# %%
retrieval_chain
# Out:
# RunnableBinding(bound=RunnableAssign(mapper={
#   context: RunnableBinding(bound=RunnableLambda(lambda x: x['input'])
#            | VectorStoreRetriever(tags=['FAISS', 'OllamaEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x0000021426FA08B0>, search_kwargs={}), kwargs={}, config={'run_name': 'retrieve_documents'}, config_factories=[])
# })
# | RunnableAssign(mapper={
#     answer: RunnableBinding(bound=RunnableBinding(bound=RunnableAssign(mapper={
#               context: RunnableLambda(format_docs)
#             }), kwargs={}, config={'run_name': 'format_inputs'}, config_factories=[])
#             | ChatPromptTemplate(input_variables=['context'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context'], input_types={}, partial_variables={}, template='\n    Answer the following question based on the the provided context:\n    <context>\n    {context}\n    </context>\n\n'), additional_kwargs={})])
#             | ChatOllama(model='gemma:2b')
#             | StrOutputParser(), kwargs={}, config={'run_name': 'stuff_documents_chain'}, config_factories=[])
#   }), kwargs={}, config={'run_name': 'retrieval_chain'}, config_factories=[])

# %%
## get the response from the llm
response = retrieval_chain.invoke(
    {
        "input":"LangSmith is a framework-agnostic platform for developing, debugging,",
    }
)

# %%
print(response)
# Out:
# {'input': 'LangSmith is a framework-agnostic platform for developing, debugging,', 'context': [Document(id='37512f23-04bd-4cf3-b6dd-7ec4e3a62bab', metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='\u200bMore ways to build\nFleetDesign and deploy AI agents visually without writing code.Build an agentPrompt engineeringIterate on prompts with built-in versioning and collaboration to ship improvements faster.Test your promptsLangSmith CLIQuery and manage traces, datasets, experiments, and more from the terminal.Use the CLIStudioUse a visual interface to design, test, and refine applications end-to-end.Develop with Studio\n\u200bInfrastructure\nPlatform setupUse LangSmith in managed cloud, in a self-hosted environment, or hybrid to match your infrastructure and compliance needs.Choose how to set up LangSmithSecurity & complianceLangSmith meets the highest standards of data security and privacy with HIPAA, SOC 2 Type 2, and GDPR compliance.Visit Trust Center\n\u200bWorkflow\nLangSmith combines observability, evaluation, deployment, and platform setup in one integrated workflow—from local development to production.'), Document(id='5790f6a8-9dd6-4736-9af5-aac30c72ef77', metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='\u200bGet started\nCreate an accountSign up at smith.langchain.com (no credit card required).\nYou can log in with Google, GitHub, or email.Create an API keyGo to your Settings page → API Keys → Create API Key.\nCopy the key and save it securely.Choose your integrationLangSmith works with many frameworks and providers. Browse available integrations to connect your stack.\nOnce your account and API key are ready, choose a quickstart to begin building with LangSmith:\nObservabilityGain visibility into every step your application takes to debug faster and improve reliability.Start tracingEvaluationMeasure and track quality over time to ensure your AI applications are consistent and trustworthy.Evaluate your appDeploymentDeploy your agents as Agent Servers, ready to scale in production.Deploy your agents\n\u200bMore ways to build'), Document(id='662bf544-abd3-4964-88fb-886de4149264', metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='LangSmith docs - Docs by LangChainSkip to main contentJoin us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. Buy tickets >Docs by LangChain home pageLangSmithSearch...⌘KAsk AIGitHubTry LangSmithTry LangSmithSearch...NavigationLangSmith docsGet startedObservabilityEvaluationPrompt engineeringAgent deploymentPlatform setupReferenceOverviewCreate an account and API keyIntegrationsPlansEnterprise featuresAccount administrationOverviewWorkspace setupUsers & access controlBilling & usageManage organizations using the APIToolsPolly AI assistantCLISkillsSandboxesPrivate previewAdditional resourcesData & complianceFAQLangSmith statusLangSmith docsCopy pageCopy pageLangSmith is a framework-agnostic platform for building, debugging, and deploying AI agents and LLM applications. Trace requests, evaluate outputs, test prompts, and manage deployments all in one place, with your agent stack.\n\u200bGet started\nCreate an accountSign up at smith.langchain.com (no credit card required).'), Document(id='aa7e8a83-4d41-4a23-9490-4227c8be22f1', metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='Edit this page on GitHub or file an issue.Connect these docs to Claude, VSCode, and more via MCP for real-time answers.Was this page helpful?YesNoCreate an account and API keyNext⌘IDocs by LangChain home pagegithubxlinkedinyoutubeResourcesForumChangelogLangChain AcademyTrust CenterCompanyHomeAboutCareersBloggithubxlinkedinyoutube')] ...

# %%
response
# Out:
# {'input': 'LangSmith is a framework-agnostic platform for developing, debugging,',
#  'context': [Document(id='37512f23-04bd-4cf3-b6dd-7ec4e3a62bab', metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='\u200bMore ways to build\nFleetDesign and deploy AI agents visually without writing code.Build an agentPrompt engineeringIterate on prompts with built-in versioning and collaboration to ship improvements faster.Test your promptsLangSmith CLIQuery and manage traces, datasets, experiments, and more from the terminal.Use the CLIStudioUse a visual interface to design, test, and refine applications end-to-end.Develop with Studio\n\u200bInfrastructure\nPlatform setupUse LangSmith in managed cloud, in a self-hosted environment, or hybrid to match your infrastructure and compliance needs.Choose how to set up LangSmithSecurity & complianceLangSmith meets the highest standards of data security and privacy with HIPAA, SOC 2 Type 2, and GDPR compliance.Visit Trust Center\n\u200bWorkflow\nLangSmith combines observability, evaluation, deployment, and platform setup in one integrated workflow—from local development to production.'),
#   Document(id='5790f6a8-9dd6-4736-9af5-aac30c72ef77', metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='\u200bGet started\nCreate an accountSign up at smith.langchain.com (no credit card required).\nYou can log in with Google, GitHub, or email.Create an API keyGo to your Settings page → API Keys → Create API Key.\nCopy the key and save it securely.Choose your integrationLangSmith works with many frameworks and providers. Browse available integrations to connect your stack.\nOnce your account and API key are ready, choose a quickstart to begin building with LangSmith:\nObservabilityGain visibility into every step your application takes to debug faster and improve reliability.Start tracingEvaluationMeasure and track quality over time to ensure your AI applications are consistent and trustworthy.Evaluate your appDeploymentDeploy your agents as Agent Servers, ready to scale in production.Deploy your agents\n\u200bMore ways to build'),
#   Document(id='662bf544-abd3-4964-88fb-886de4149264', metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='LangSmith docs - Docs by LangChainSkip to main contentJoin us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. Buy tickets >Docs by LangChain home pageLangSmithSearch...⌘KAsk AIGitHubTry LangSmithTry LangSmithSearch...NavigationLangSmith docsGet startedObservabilityEvaluationPrompt engineeringAgent deploymentPlatform setupReferenceOverviewCreate an account and API keyIntegrationsPlansEnterprise featuresAccount administrationOverviewWorkspace setupUsers & access controlBilling & usageManage organizations using the APIToolsPolly AI assistantCLISkillsSandboxesPrivate previewAdditional resourcesData & complianceFAQLangSmith statusLangSmith docsCopy pageCopy pageLangSmith is a framework-agnostic platform for building, debugging, and deploying AI agents and LLM applications. Trace requests, evaluate outputs, test prompts, and manage deployments all in one place, with your agent stack.\n\u200bGet started\nCreate an accountSign up at smith.langchain.com (no credit card required).'),
#   Document(id='aa7e8a83-4d41-4a23-9490-4227c8be22f1', metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='Edit this page on GitHub or file an issue.Connect these docs to Claude, VSCode, and more via MCP for real-time answers.Was this page helpful?YesNoCreate an account and API keyNext⌘IDocs by LangChain home pagegithubxlinkedinyoutubeResourcesForumChangelogLangChain AcademyTrust CenterCompanyHomeAboutCareersBloggithubxlinkedinyoutube')],
#  'answer': 'The context does not provide any information about the answer to the question, so I cannot answer this question from the provided context.'}

# %%
response['answer']
# Out:
# 'The context does not provide any information about the answer to the question, so I cannot answer this question from the provided context.'

# %%
response['context']
# Out:
# [Document(id='37512f23-04bd-4cf3-b6dd-7ec4e3a62bab', metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='\u200bMore ways to build\nFleetDesign and deploy AI agents visually without writing code.Build an agentPrompt engineeringIterate on prompts with built-in versioning and collaboration to ship improvements faster.Test your promptsLangSmith CLIQuery and manage traces, datasets, experiments, and more from the terminal.Use the CLIStudioUse a visual interface to design, test, and refine applications end-to-end.Develop with Studio\n\u200bInfrastructure\nPlatform setupUse LangSmith in managed cloud, in a self-hosted environment, or hybrid to match your infrastructure and compliance needs.Choose how to set up LangSmithSecurity & complianceLangSmith meets the highest standards of data security and privacy with HIPAA, SOC 2 Type 2, and GDPR compliance.Visit Trust Center\n\u200bWorkflow\nLangSmith combines observability, evaluation, deployment, and platform setup in one integrated workflow—from local development to production.'),
#  Document(id='5790f6a8-9dd6-4736-9af5-aac30c72ef77', metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='\u200bGet started\nCreate an accountSign up at smith.langchain.com (no credit card required).\nYou can log in with Google, GitHub, or email.Create an API keyGo to your Settings page → API Keys → Create API Key.\nCopy the key and save it securely.Choose your integrationLangSmith works with many frameworks and providers. Browse available integrations to connect your stack.\nOnce your account and API key are ready, choose a quickstart to begin building with LangSmith:\nObservabilityGain visibility into every step your application takes to debug faster and improve reliability.Start tracingEvaluationMeasure and track quality over time to ensure your AI applications are consistent and trustworthy.Evaluate your appDeploymentDeploy your agents as Agent Servers, ready to scale in production.Deploy your agents\n\u200bMore ways to build'),
#  Document(id='662bf544-abd3-4964-88fb-886de4149264', metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='LangSmith docs - Docs by LangChainSkip to main contentJoin us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. Buy tickets >Docs by LangChain home pageLangSmithSearch...⌘KAsk AIGitHubTry LangSmithTry LangSmithSearch...NavigationLangSmith docsGet startedObservabilityEvaluationPrompt engineeringAgent deploymentPlatform setupReferenceOverviewCreate an account and API keyIntegrationsPlansEnterprise featuresAccount administrationOverviewWorkspace setupUsers & access controlBilling & usageManage organizations using the APIToolsPolly AI assistantCLISkillsSandboxesPrivate previewAdditional resourcesData & complianceFAQLangSmith statusLangSmith docsCopy pageCopy pageLangSmith is a framework-agnostic platform for building, debugging, and deploying AI agents and LLM applications. Trace requests, evaluate outputs, test prompts, and manage deployments all in one place, with your agent stack.\n\u200bGet started\nCreate an accountSign up at smith.langchain.com (no credit card required).'),
#  Document(id='aa7e8a83-4d41-4a23-9490-4227c8be22f1', metadata={'source': 'https://docs.langchain.com/langsmith/home', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='Edit this page on GitHub or file an issue.Connect these docs to Claude, VSCode, and more via MCP for real-time answers.Was this page helpful?YesNoCreate an account and API keyNext⌘IDocs by LangChain home pagegithubxlinkedinyoutubeResourcesForumChangelogLangChain AcademyTrust CenterCompanyHomeAboutCareersBloggithubxlinkedinyoutube')]
